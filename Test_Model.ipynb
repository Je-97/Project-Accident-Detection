# %% [markdown]
# # Import Necessary Libraries

# %%
# %%capture
# !pip install ultralytics

# %%
# import necessary libraries
import os
import cv2
from ultralytics import YOLO

# %% [markdown]
# # Load Best Model

# %%
best_model = YOLO('/content/best.pt')

# %% [markdown]
# # Images Testing

# %%
# for testing image
# Define the input image and output directory
input_image = '/content/traffic_img129_jpg.rf.5f2b657ee5bd2f6eede14c7f853554de.jpg'
output_dir = '/content/output/'

os.makedirs(output_dir, exist_ok=True)

# Read image
image = cv2.imread(input_image)

# Apply the model to the image
results = best_model(image)

# Draw bounding boxes on the image
annotated_image = results[0].plot()

# the output path for the annotated image
output_image = os.path.join(output_dir, 'car2_out.jpg')

# Save the image with detection
cv2.imwrite(output_image, annotated_image)
# Out:
# 0: 640x640 1 severe, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# True

# %% [markdown]
# # Open Video

# %%
video_path = '/content/video1.mp4'
cap = cv2.VideoCapture(video_path)
print(cap.isOpened()) # To insure the video is opened
# Out:
# True

# %%
# Get Video information
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
# Writer Video
output_video = 'output_acc2.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video, fourcc, fps, (width, height))

# %% [markdown]
# # Testing Video

# %%
# Here is about read the video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Here is about applying the model to the frame
    results = best_model(frame)

    # Here is about draw bounding box
    annotated_frame = results[0].plot()

    # Here is about write  to output
    out.write(annotated_frame)

# Here is about release and close videos
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 (no detections), 83.1ms
# Speed: 1.6ms preprocess, 83.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 1.2ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 1.3ms preprocess, 10.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# ...
